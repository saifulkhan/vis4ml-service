# %%
import warnings

warnings.filterwarnings(
    "ignore", category=RuntimeWarning, message="overflow encountered in exp"
)

# %%
from infomeasure import entropy

# %%
h_discrete = entropy([1], approach="discrete", base=2)
print(h_discrete)
# Out:
# -0.0

# %%
h_discrete = entropy([1, 2], approach="discrete", base=2)
print(h_discrete)
# Out:
# 1.0

# %%
h_discrete = entropy([1, 2, 3, 4], approach="discrete", base=2)
print(h_discrete)
# Out:
# 2.0

# %%
h_discrete = entropy([[1, 2, 4], [3, 0, 9]], approach="discrete", base=2)
print(h_discrete)
# Out:
# 1.0

# %%
h_discrete = entropy([[1, 2, 4], [1, 2, 4]], approach="discrete", base=2)
print(h_discrete)
# Out:
# -0.0

# %%
h_discrete = entropy(
    [[3, 0, 9], [3, 0, 9], [3, 0, 9], [3, 0, 9]], approach="discrete", base=2
)
print(h_discrete)
# Out:
# -0.0

# %%
h_discrete = entropy(
    [[3, 0, 9], [3, 0, 9], [3, 0, 0], [3, 0, 0]], approach="discrete", base=2
)
print(h_discrete)
# Out:
# 1.0

# %%
h_discrete = entropy(
    [[3, 0, 9], [3, 0, 0], [0, 0, 0], [3, 0, 1]], approach="discrete", base=2
)
print(h_discrete)
# Out:
# 2.0

# %%
h_discrete = entropy([1, 2, 3, 0], approach="discrete", base=2)
print(h_discrete)
# Out:
# 2.0
